# %% [markdown]
# <a href="https://colab.research.google.com/github/pablolorenzomicheli-oss/Proyecto_Mentoria_FAMAF_2026/blob/main/GRUPO_1_Entregable_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
import plotly.express as px
import numpy as np
import pandas as pd
import io

# %matplotlib inline

# %%
# DEsempeño en Lengua
# url = "https://raw.githubusercontent.com/pablolorenzomicheli-oss/Proyecto_Mentoria_FAMAF_2026/main/data/raw/2024%20Base%20APRENDER%20-%20Censal%20-%20Secundaria%205-6%20a%C3%B1o%20-%20Agregada%20-%20Desempe%C3%B1os%20de%20Lengua(in).csv"

url = "https://raw.githubusercontent.com/pablolorenzomicheli-oss/Proyecto_Mentoria_FAMAF_2026/main/data/raw/2024%20Base%20APRENDER%20-%20Censal%20-%20Secundaria%205-6%20a%C3%B1o%20-%20Agregada%20-%20Desempe%C3%B1os%20de%20Matematica(in).csv"

df = pd.read_csv(
    url,
    sep=";",
    encoding="cp1252"
)

df.head()
# Out:
#                       jurisdiccion departamento   sector  ambito ap01_Blanco  \
# 0  Ciudad Autónoma de Buenos Aires     Comuna 1  Estatal  Urbano
# 1  Ciudad Autónoma de Buenos Aires     Comuna 1  Privado  Urbano
# 2  Ciudad Autónoma de Buenos Aires    Comuna 10  Estatal  Urbano
# 3  Ciudad Autónoma de Buenos Aires    Comuna 10  Privado  Urbano
# 4  Ciudad Autónoma de Buenos Aires    Comuna 11  Estatal  Urbano
#
#   ap01_No_disponible ap01_Multimarca   ap01_Enero ap01_Febrero   ap01_Marzo  \
# 0                                     146,2063165  154,3499187  155,7769437
# 1                                     138,6054147  104,6391649  104,1424043
# 2                                      69,4946682   93,2044307   78,7659049
# 3                                     105,5570206    79,142254   90,8757785
# 4                                      73,8012536   51,0019555   59,0418048
#
#    ... Nivel_Ed_Persona_Resp_Primaria_incompleto  \
# 0  ...                                16,3830199
# 1  ...
# 2  ...                                 6,1453459
# 3  ...                                 1,2535105
# 4  ...                                 3,8584855
#
#   Nivel_Ed_Persona_Resp_Primaria_completo  \
# 0                              15,4603588
# 1                               7,3237249
# 2                               4,7525403
# 3                                2,395605
# 4                               1,3621453
#
#   Nivel_Ed_Persona_Resp_Secundaria_incompleto  \
# 0                                  33,7455992
# 1                                  14,5903122
# 2                                   30,621707
# 3                                  19,4664798
# 4                                  35,3867671
#
#   Nivel_Ed_Persona_Resp_Secundaria_completo  \
# 0                                70,7846737
# 1                                35,7620109
# 2                                53,9464201
# 3                                41,4227258
# 4                                43,8035823
#
#   Nivel_Ed_Persona_Resp_Terciariouniversitarioposgrado_incompleto  \
# 0                                         22,9418978
# 1                                         24,7096798
# 2                                         17,6777909
# 3                                         29,6314758
# 4                                         11,8932495
#
#   Nivel_Ed_Persona_Resp_Terciariouniversitarioposgrado_completo  \
# 0                                        143,5590856
# 1                                        101,4423196
# 2                                         44,8217913
# 3                                         96,8265148
# 4                                         23,1253164
#
#   mdesemp_Por_debajo_del_nivel_básico mdesemp_Básico mdesemp_Satisfactorio  \
# 0                         665,7173151    441,5378815           628,9093214
# 1                         321,9486713    354,4338953           533,8138828
# 2                         319,3978447    274,6571387           339,4560426
# 3                         335,2319491    400,6326516           481,5261757
# 4                          339,909672    212,2942199           167,8839804
#
#   mdesemp_Avanzado
# 0       24,0995975
# 1       18,4947311
# 2        8,5605506
# 3        4,8909331
# 4        3,1853247
#
# [5 rows x 1035 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.path.exists("data/raw/Base_publica_prim_Ap2024.sav")
# Out:
# False
