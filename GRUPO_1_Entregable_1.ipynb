# %% [markdown]
# <a href="https://colab.research.google.com/github/pablolorenzomicheli-oss/Proyecto_Mentoria_FAMAF_2026/blob/main/GRUPO_1_Entregable_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
import plotly.express as px
import numpy as np
import pandas as pd
import io

# %matplotlib inline

# %%
# DEsempeño en Lengua
# url = "https://raw.githubusercontent.com/pablolorenzomicheli-oss/Proyecto_Mentoria_FAMAF_2026/main/data/raw/2024%20Base%20APRENDER%20-%20Censal%20-%20Secundaria%205-6%20a%C3%B1o%20-%20Agregada%20-%20Desempe%C3%B1os%20de%20Lengua(in).csv"

# url = "https://raw.githubusercontent.com/pablolorenzomicheli-oss/Proyecto_Mentoria_FAMAF_2026/main/data/raw/2024%20Base%20APRENDER%20-%20Censal%20-%20Secundaria%205-6%20a%C3%B1o%20-%20Agregada%20-%20Desempe%C3%B1os%20de%20Matematica(in).csv"

url = "/content/2024 Base APRENDER - Censal - Secundaria 5-6 año - Agregada - Desempeños de Matematica.xlsx"
df = pd.read_excel(url)

df
# Out:
#                                            jurisdiccion departamento   sector  \
# 0                       Ciudad Autónoma de Buenos Aires     Comuna 1  Estatal
# 1                       Ciudad Autónoma de Buenos Aires     Comuna 1  Privado
# 2                       Ciudad Autónoma de Buenos Aires    Comuna 10  Estatal
# 3                       Ciudad Autónoma de Buenos Aires    Comuna 10  Privado
# 4                       Ciudad Autónoma de Buenos Aires    Comuna 11  Estatal
# ...                                                 ...          ...      ...
# 1170  Tierra del Fuego, Antártida e Islas del Atlánt...   RIO GRANDE  Estatal
# 1171  Tierra del Fuego, Antártida e Islas del Atlánt...   RIO GRANDE  Privado
# 1172  Tierra del Fuego, Antártida e Islas del Atlánt...      TOLHUIN  Estatal
# 1173  Tierra del Fuego, Antártida e Islas del Atlánt...      USHUAIA  Estatal
# 1174  Tierra del Fuego, Antártida e Islas del Atlánt...      USHUAIA  Privado
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.path.exists("data/raw/Base_publica_prim_Ap2024.sav")
# Out:
# False
